# %% [markdown]
# <a href="https://colab.research.google.com/github/pulkit1230/Data-analysis/blob/main/websitedataanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import yfinance as yf

# %%
tcs=yf.download("601138.SS")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tcs
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914
# ...               ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578
# 2025-04-18  17.559999  17.650000  17.350000  17.400000   54420200
#
# [1660 rows x 5 columns]

# %%
df=pd.DataFrame(tcs)
df
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914
# ...               ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578
# 2025-04-18  17.559999  17.650000  17.350000  17.400000   54420200
#
# [1660 rows x 5 columns]

# %%
df.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914

# %%
df.tail(200)
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2024-06-24  26.802618  27.697660  26.578858  27.045836  113412966
# 2024-06-25  25.722733  26.462115  25.498971  26.034051  131710039
# 2024-06-26  26.432928  26.637230  25.732461  26.384285  119786129
# 2024-06-27  26.082693  26.510757  25.605986  25.946492  105659504
# 2024-06-28  26.656689  27.026381  25.965951  25.975679  115006111
# ...               ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578
# 2025-04-18  17.559999  17.650000  17.350000  17.400000   54420200
#
# [200 rows x 5 columns]

# %%
df[1600:1613]
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2025-01-16  20.840000  20.990000  20.200001  20.350000  157268995
# 2025-01-17  20.660000  21.000000  20.500000  20.680000  102381225
# 2025-01-20  20.770000  21.090000  20.690001  20.910000   84717471
# 2025-01-21  21.209999  21.600000  20.750000  20.959999  125772325
# 2025-01-22  23.330000  23.330000  21.410000  21.420000  399541198
# 2025-01-23  23.000000  24.240000  23.000000  23.809999  404504805
# 2025-01-24  23.350000  23.500000  22.559999  22.709999  231955256
# 2025-01-27  21.450001  22.590000  21.389999  22.549999  254718757
# 2025-02-05  20.000000  20.590000  19.799999  20.559999  299566077
# 2025-02-06  20.480000  20.570000  20.000000  20.309999  204003961
# 2025-02-07  21.549999  21.910000  20.590000  20.670000  289325724
# 2025-02-10  21.719999  21.780001  21.430000  21.660000  172621877
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1660 entries, 2018-06-13 to 2025-04-18
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   (Close, 601138.SS)   1660 non-null   float64
#  1   (High, 601138.SS)    1660 non-null   float64
#  2   (Low, 601138.SS)     1660 non-null   float64
#  3   (Open, 601138.SS)    1660 non-null   float64
#  4   (Volume, 601138.SS)  1660 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 77.8 KB

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker    601138.SS    601138.SS    601138.SS    601138.SS     601138.SS
# count   1660.000000  1660.000000  1660.000000  1660.000000  1.660000e+03
# mean      14.140043    14.395303    13.877346    14.120954  7.624124e+07
# std        4.835053     4.985306     4.672652     4.818334  7.312948e+07
# min        7.746119     7.831554     7.404379     7.470828  0.000000e+00
# 25%       10.603646    10.740951    10.502540    10.600396  2.523295e+07
# 50%       12.545319    12.744014    12.395056    12.567539  4.714476e+07
# 75%       16.466223    16.771970    16.004960    16.258986  1.025720e+08
# max       28.213284    28.670532    27.649018    28.651076  6.332171e+08

# %%
df.std()
# Out:
# Price   Ticker
# Close   601138.SS    4.835053e+00
# High    601138.SS    4.985306e+00
# Low     601138.SS    4.672652e+00
# Open    601138.SS    4.818334e+00
# Volume  601138.SS    7.312948e+07
# dtype: float64

# %%
df[['Close','Volume','Open']].plot(subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df['simple_rtn']=df.Close.pct_change()
df['simple_rtn']
# Out:
# Date
# 2018-06-13         NaN
# 2018-06-14   -0.094479
# 2018-06-15   -0.030485
# 2018-06-19   -0.100089
# 2018-06-20   -0.022638
#                 ...
# 2025-04-14    0.006742
# 2025-04-15    0.010045
# 2025-04-16   -0.033149
# 2025-04-17   -0.005714
# 2025-04-18    0.009195
# Name: simple_rtn, Length: 1660, dtype: float64

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
import numpy as np
df['clog_rtn']=np.log(df.Close/df.Close.shift(1))
df['clog_rtn']
# Out:
# Date
# 2018-06-13         NaN
# 2018-06-14   -0.099245
# 2018-06-15   -0.030960
# 2018-06-19   -0.105459
# 2018-06-20   -0.022898
#                 ...
# 2025-04-14    0.006719
# 2025-04-15    0.009995
# 2025-04-16   -0.033711
# 2025-04-17   -0.005731
# 2025-04-18    0.009153
# Name: clog_rtn, Length: 1660, dtype: float64

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df[1600:]
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2025-01-16  20.840000  20.990000  20.200001  20.350000  157268995   0.034757
# 2025-01-17  20.660000  21.000000  20.500000  20.680000  102381225  -0.008637
# 2025-01-20  20.770000  21.090000  20.690001  20.910000   84717471   0.005324
# 2025-01-21  21.209999  21.600000  20.750000  20.959999  125772325   0.021184
# 2025-01-22  23.330000  23.330000  21.410000  21.420000  399541198   0.099953
# 2025-01-23  23.000000  24.240000  23.000000  23.809999  404504805  -0.014145
# 2025-01-24  23.350000  23.500000  22.559999  22.709999  231955256   0.015217
# 2025-01-27  21.450001  22.590000  21.389999  22.549999  254718757  -0.081370
# 2025-02-05  20.000000  20.590000  19.799999  20.559999  299566077  -0.067599
# 2025-02-06  20.480000  20.570000  20.000000  20.309999  204003961   0.024000
# ...

# %%
df.tail(10)
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2025-04-07  17.150000  17.150000  17.150000  17.150000   33166200  -0.099738
# 2025-04-08  15.440000  16.639999  15.440000  16.290001  214740384  -0.099708
# 2025-04-09  16.330000  16.500000  14.580000  14.580000  218935510   0.057643
# 2025-04-10  17.959999  17.959999  17.500000  17.900000  253856136   0.099816
# 2025-04-11  17.799999  18.090000  17.379999  17.650000  157423758  -0.008909
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# 2025-04-18  17.559999  17.650000  17.350000  17.400000   54420200   0.009195
#
# Price       clog_rtn
# Ticker
# Date
# ...

# %%
df['Volume'].plot(figsize=(12,8),title='TCS')
# Out:
# <Axes: title={'center': 'TCS'}, xlabel='Date'>

# %%
df[['Close','Volume','Open']].plot(figsize=(12,8),title='TCS')
# Out:
# <Axes: title={'center': 'TCS'}, xlabel='Date'>

# %%
df[['Close','Volume','Open']].plot(figsize=(12,8),style='b',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df.isnull().sum()
# Out:
# Price       Ticker
# Close       601138.SS    0
# High        601138.SS    0
# Low         601138.SS    0
# Open        601138.SS    0
# Volume      601138.SS    0
# simple_rtn               1
# clog_rtn                 1
# dtype: int64

# %%
df['vsimple_rtn']=df.Volume.pct_change()
df['vsimple_rtn']
# Out:
# Date
# 2018-06-13         NaN
# 2018-06-14   -0.450770
# 2018-06-15   -0.385046
# 2018-06-19   -0.018246
# 2018-06-20   -0.055703
#                 ...
# 2025-04-14   -0.092223
# 2025-04-15   -0.388392
# 2025-04-16    0.358378
# 2025-04-17   -0.344515
# 2025-04-18   -0.300715
# Name: vsimple_rtn, Length: 1660, dtype: float64

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df[['simple_rtn','vsimple_rtn']].plot(figsize=(12,8),style='b',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df['vlog_rtn']=np.log(df.Volume/df.Volume.shift(1))
df['vlog_rtn']
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# Date
# 2018-06-13         NaN
# 2018-06-14   -0.599237
# 2018-06-15   -0.486208
# 2018-06-19   -0.018415
# 2018-06-20   -0.057314
#                 ...
# 2025-04-14   -0.096757
# 2025-04-15   -0.491663
# 2025-04-16    0.306291
# 2025-04-17   -0.422381
# 2025-04-18   -0.357696
# Name: vlog_rtn, Length: 1660, dtype: float64

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df[['clog_rtn','vlog_rtn']].plot(figsize=(12,8),style='b',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
WINDOW_SIZE = 12
df['rolling_mean'] = df.Close.rolling(window=WINDOW_SIZE).mean()
df['rolling_std'] = df.Close.rolling(window=WINDOW_SIZE).std()

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
WIND0W_SIZE = 10
df['Vrolling_mean'] = df.Volume.rolling(window=WINDOW_SIZE).mean()
df['Vrolling_std'] = df.Volume.rolling(window=WINDOW_SIZE).std()

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df[:100]
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2018-11-02  10.855009  10.966916  10.648411  10.889442   49601038   0.021052
# 2018-11-05  10.846403  10.975527  10.725887  10.863619   35546773  -0.000793
# 2018-11-06  11.009960  11.061610  10.596764  10.760321   39011940   0.015079
# 2018-11-07  10.786144  11.053001  10.725887  10.949702   31397467  -0.020328
# ...

# %%
df[:20]
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# 2018-06-21  15.641204  17.027134  15.537904  16.872185  197849535  -0.085095
# 2018-06-22  16.114656  16.510637  15.090275  15.236615  175575007   0.030270
# 2018-06-25  15.675632  16.149088  15.606766  16.028572  115443049  -0.027244
# 2018-06-26  15.951097  16.063003  15.107486  15.271044  113725844   0.017573
# 2018-06-27  15.727284  16.235172  15.649810  15.925274   97039103  -0.014031
# ...

# %%
df[['rolling_mean','Vrolling_mean']].plot(figsize=(12,8),style='b',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df['logrolling_mean'] = np.log(df.rolling_mean/df.rolling_mean.shift(1))
df['logrolling_std']=np.log(df.rolling_std/df.rolling_std.shift(1))

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df['vlogrolling_mean'] = np.log(df.Vrolling_mean/df.rolling_mean.shift(1))
df['vlogrolling_std']=np.log(df.Vrolling_std/df.rolling_std.shift(1))

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df[['logrolling_mean','logrolling_std']].plot(figsize=(12,8),style='b',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df[['vlogrolling_mean','vlogrolling_std']].plot(figsize=(12,8),style='b',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df[['logrolling_mean','logrolling_std']].plot(figsize=(12,8),style='b',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df[['logrolling_mean','vlogrolling_mean']].plot(figsize=(12,8),style='b',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df[['logrolling_std','vlogrolling_std']].plot(figsize=(12,8),style='b',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df.isnull().sum()
# Out:
# Price             Ticker
# Close             601138.SS     0
# High              601138.SS     0
# Low               601138.SS     0
# Open              601138.SS     0
# Volume            601138.SS     0
# simple_rtn                      1
# clog_rtn                        1
# vsimple_rtn                     1
# vlog_rtn                        1
# rolling_mean                   11
# rolling_std                    11
# Vrolling_mean                  11
# Vrolling_std                   11
# logrolling_mean                12
# logrolling_std                 12
# vlogrolling_mean               12
# vlogrolling_std                12
# dtype: int64

# %%
df.dropna(how = 'all')
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df.isnull().sum()
# Out:
# Price             Ticker
# Close             601138.SS     0
# High              601138.SS     0
# Low               601138.SS     0
# Open              601138.SS     0
# Volume            601138.SS     0
# simple_rtn                      1
# clog_rtn                        1
# vsimple_rtn                     1
# vlog_rtn                        1
# rolling_mean                   11
# rolling_std                    11
# Vrolling_mean                  11
# Vrolling_std                   11
# logrolling_mean                12
# logrolling_std                 12
# vlogrolling_mean               12
# vlogrolling_std                12
# dtype: int64

# %%
df.fillna(0)
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140434  22.691364  20.281051  21.133268  633217109   0.000000
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437441  19.910894  18.955379  19.454658  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095995  17.440325  16.364293  17.044344  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df.isnull().sum()
# Out:
# Price             Ticker
# Close             601138.SS     0
# High              601138.SS     0
# Low               601138.SS     0
# Open              601138.SS     0
# Volume            601138.SS     0
# simple_rtn                      1
# clog_rtn                        1
# vsimple_rtn                     1
# vlog_rtn                        1
# rolling_mean                   11
# rolling_std                    11
# Vrolling_mean                  11
# Vrolling_std                   11
# logrolling_mean                12
# logrolling_std                 12
# vlogrolling_mean               12
# vlogrolling_std                12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Price             Ticker
# Close             601138.SS    0
# High              601138.SS    0
# Low               601138.SS    0
# Open              601138.SS    0
# Volume            601138.SS    0
# simple_rtn                     0
# clog_rtn                       0
# vsimple_rtn                    0
# vlog_rtn                       0
# rolling_mean                   0
# rolling_std                    0
# Vrolling_mean                  0
# Vrolling_std                   0
# logrolling_mean                0
# logrolling_std                 0
# vlogrolling_mean               0
# vlogrolling_std                0
# dtype: int64

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-07-02  15.141922  15.796150  14.720118  15.667026  121806604  -0.046095
# 2018-07-03  15.408777  15.469035  14.720117  15.098881   89742495   0.017624
# 2018-07-04  14.780376  15.382955  14.737336  15.236615   80724110  -0.040782
# 2018-07-05  14.599602  15.064448  14.384395  14.634036   91199252  -0.012231
# 2018-07-06  14.832026  15.219398  14.461870  14.556562  105690560   0.015920
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [(Close, 601138.SS), (High, 601138.SS), (Low, 601138.SS), (Open, 601138.SS), (Volume, 601138.SS), (simple_rtn, ), (clog_rtn, ), (vsimple_rtn, ), (vlog_rtn, ), (rolling_mean, ), (rolling_std, ), (Vrolling_mean, ), (Vrolling_std, ), (logrolling_mean, ), (logrolling_std, ), (vlogrolling_mean, ), (vlogrolling_std, )]
# Index: []

# %%
df.describe()
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# Price         Close         High          Low         Open        Volume  \
# Ticker    601138.SS    601138.SS    601138.SS    601138.SS     601138.SS
# count   1648.000000  1648.000000  1648.000000  1648.000000  1.648000e+03
# mean      14.117642    14.370096    13.856761    14.097568  7.526913e+07
# std        4.842196     4.991044     4.680647     4.824616  7.143332e+07
# min        7.746119     7.831554     7.404379     7.470828  0.000000e+00
# 25%       10.590127    10.725320    10.481490    10.591215  2.515356e+07
# 50%       12.531750    12.720424    12.364189    12.537096  4.664040e+07
# 75%       16.458387    16.676447    15.976677    16.231240  1.009938e+08
# max       28.213284    28.670532    27.649018    28.651076  5.506132e+08
#
# ...

# %%
#df['logrolling_mean'] = df['simple_rtn'].apply(lambda x: x if x >= 0 else np.nan)

# %%
df.describe()
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# Price         Close         High          Low         Open        Volume  \
# Ticker    601138.SS    601138.SS    601138.SS    601138.SS     601138.SS
# count   1648.000000  1648.000000  1648.000000  1648.000000  1.648000e+03
# mean      14.117642    14.370096    13.856761    14.097568  7.526913e+07
# std        4.842196     4.991044     4.680647     4.824616  7.143332e+07
# min        7.746119     7.831554     7.404379     7.470828  0.000000e+00
# 25%       10.590127    10.725320    10.481490    10.591215  2.515356e+07
# 50%       12.531750    12.720424    12.364189    12.537096  4.664040e+07
# 75%       16.458387    16.676447    15.976677    16.231240  1.009938e+08
# max       28.213284    28.670532    27.649018    28.651076  5.506132e+08
#
# ...

# %%
#df['logrolling_std'] = df['simple_rtn'].apply(lambda x: x if x >= 0 else np.nan)

# %%
df.describe()
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# Price         Close         High          Low         Open        Volume  \
# Ticker    601138.SS    601138.SS    601138.SS    601138.SS     601138.SS
# count   1648.000000  1648.000000  1648.000000  1648.000000  1.648000e+03
# mean      14.117642    14.370096    13.856761    14.097568  7.526913e+07
# std        4.842196     4.991044     4.680647     4.824616  7.143332e+07
# min        7.746119     7.831554     7.404379     7.470828  0.000000e+00
# 25%       10.590127    10.725320    10.481490    10.591215  2.515356e+07
# 50%       12.531750    12.720424    12.364189    12.537096  4.664040e+07
# 75%       16.458387    16.676447    15.976677    16.231240  1.009938e+08
# max       28.213284    28.670532    27.649018    28.651076  5.506132e+08
#
# ...

# %%
df.describe()
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# Price         Close         High          Low         Open        Volume  \
# Ticker    601138.SS    601138.SS    601138.SS    601138.SS     601138.SS
# count   1648.000000  1648.000000  1648.000000  1648.000000  1.648000e+03
# mean      14.117642    14.370096    13.856761    14.097568  7.526913e+07
# std        4.842196     4.991044     4.680647     4.824616  7.143332e+07
# min        7.746119     7.831554     7.404379     7.470828  0.000000e+00
# 25%       10.590127    10.725320    10.481490    10.591215  2.515356e+07
# 50%       12.531750    12.720424    12.364189    12.537096  4.664040e+07
# 75%       16.458387    16.676447    15.976677    16.231240  1.009938e+08
# max       28.213284    28.670532    27.649018    28.651076  5.506132e+08
#
# ...

# %%
df.isnull().sum()
# Out:
# Price             Ticker
# Close             601138.SS    0
# High              601138.SS    0
# Low               601138.SS    0
# Open              601138.SS    0
# Volume            601138.SS    0
# simple_rtn                     0
# clog_rtn                       0
# vsimple_rtn                    0
# vlog_rtn                       0
# rolling_mean                   0
# rolling_std                    0
# Vrolling_mean                  0
# Vrolling_std                   0
# logrolling_mean                0
# logrolling_std                 0
# vlogrolling_mean               0
# vlogrolling_std                0
# dtype: int64

# %%
df.dropna()
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-07-02  15.141922  15.796150  14.720118  15.667026  121806604  -0.046095
# 2018-07-03  15.408777  15.469035  14.720117  15.098881   89742495   0.017624
# 2018-07-04  14.780376  15.382955  14.737336  15.236615   80724110  -0.040782
# 2018-07-05  14.599602  15.064448  14.384395  14.634036   91199252  -0.012231
# 2018-07-06  14.832026  15.219398  14.461870  14.556562  105690560   0.015920
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df.isnull().sum()
# Out:
# Price             Ticker
# Close             601138.SS    0
# High              601138.SS    0
# Low               601138.SS    0
# Open              601138.SS    0
# Volume            601138.SS    0
# simple_rtn                     0
# clog_rtn                       0
# vsimple_rtn                    0
# vlog_rtn                       0
# rolling_mean                   0
# rolling_std                    0
# Vrolling_mean                  0
# Vrolling_std                   0
# logrolling_mean                0
# logrolling_std                 0
# vlogrolling_mean               0
# vlogrolling_std                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Price             Ticker
# Close             601138.SS    0
# High              601138.SS    0
# Low               601138.SS    0
# Open              601138.SS    0
# Volume            601138.SS    0
# simple_rtn                     0
# clog_rtn                       0
# vsimple_rtn                    0
# vlog_rtn                       0
# rolling_mean                   0
# rolling_std                    0
# Vrolling_mean                  0
# Vrolling_std                   0
# logrolling_mean                0
# logrolling_std                 0
# vlogrolling_mean               0
# vlogrolling_std                0
# dtype: int64

# %%
df.describe()
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# Price         Close         High          Low         Open        Volume  \
# Ticker    601138.SS    601138.SS    601138.SS    601138.SS     601138.SS
# count   1648.000000  1648.000000  1648.000000  1648.000000  1.648000e+03
# mean      14.117642    14.370096    13.856761    14.097568  7.526913e+07
# std        4.842196     4.991044     4.680647     4.824616  7.143332e+07
# min        7.746119     7.831554     7.404379     7.470828  0.000000e+00
# 25%       10.590127    10.725320    10.481490    10.591215  2.515356e+07
# 50%       12.531750    12.720424    12.364189    12.537096  4.664040e+07
# 75%       16.458387    16.676447    15.976677    16.231240  1.009938e+08
# max       28.213284    28.670532    27.649018    28.651076  5.506132e+08
#
# ...

# %%
df.dtypes
# Out:
# Price             Ticker
# Close             601138.SS    float64
# High              601138.SS    float64
# Low               601138.SS    float64
# Open              601138.SS    float64
# Volume            601138.SS      int64
# simple_rtn                     float64
# clog_rtn                       float64
# vsimple_rtn                    float64
# vlog_rtn                       float64
# rolling_mean                   float64
# rolling_std                    float64
# Vrolling_mean                  float64
# Vrolling_std                   float64
# logrolling_mean                float64
# logrolling_std                 float64
# vlogrolling_mean               float64
# vlogrolling_std                float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-07-02  15.141922  15.796150  14.720118  15.667026  121806604  -0.046095
# 2018-07-03  15.408777  15.469035  14.720117  15.098881   89742495   0.017624
# 2018-07-04  14.780376  15.382955  14.737336  15.236615   80724110  -0.040782
# 2018-07-05  14.599602  15.064448  14.384395  14.634036   91199252  -0.012231
# 2018-07-06  14.832026  15.219398  14.461870  14.556562  105690560   0.015920
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df.tail(10)
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2025-04-07  17.150000  17.150000  17.150000  17.150000   33166200  -0.099738
# 2025-04-08  15.440000  16.639999  15.440000  16.290001  214740384  -0.099708
# 2025-04-09  16.330000  16.500000  14.580000  14.580000  218935510   0.057643
# 2025-04-10  17.959999  17.959999  17.500000  17.900000  253856136   0.099816
# 2025-04-11  17.799999  18.090000  17.379999  17.650000  157423758  -0.008909
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# 2025-04-18  17.559999  17.650000  17.350000  17.400000   54420200   0.009195
#
# ...

# %%
df.head(5)
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-07-02  15.141922  15.796150  14.720118  15.667026  121806604  -0.046095
# 2018-07-03  15.408777  15.469035  14.720117  15.098881   89742495   0.017624
# 2018-07-04  14.780376  15.382955  14.737336  15.236615   80724110  -0.040782
# 2018-07-05  14.599602  15.064448  14.384395  14.634036   91199252  -0.012231
# 2018-07-06  14.832026  15.219398  14.461870  14.556562  105690560   0.015920
#
# Price       clog_rtn vsimple_rtn  vlog_rtn rolling_mean rolling_std  \
# Ticker
# Date
# 2018-07-02 -0.047192   -0.046899 -0.048035    16.633302    1.602772
# 2018-07-03  0.017470   -0.263238 -0.305490    16.246648    1.217249
# 2018-07-04 -0.041637   -0.100492 -0.105907    15.858559    0.766342
# 2018-07-05 -0.012306    0.129765  0.122009    15.617528    0.652259
# 2018-07-06  0.015794    0.158897  0.147469    15.428864    0.493952
#
# ...

# %%
#df.sort_values(by='simple_rtn', ascending=True, inplace=True)

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-07-02  15.141922  15.796150  14.720118  15.667026  121806604  -0.046095
# 2018-07-03  15.408777  15.469035  14.720117  15.098881   89742495   0.017624
# 2018-07-04  14.780376  15.382955  14.737336  15.236615   80724110  -0.040782
# 2018-07-05  14.599602  15.064448  14.384395  14.634036   91199252  -0.012231
# 2018-07-06  14.832026  15.219398  14.461870  14.556562  105690560   0.015920
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-07-02  15.141922  15.796150  14.720118  15.667026  121806604  -0.046095
# 2018-07-03  15.408777  15.469035  14.720117  15.098881   89742495   0.017624
# 2018-07-04  14.780376  15.382955  14.737336  15.236615   80724110  -0.040782
# 2018-07-05  14.599602  15.064448  14.384395  14.634036   91199252  -0.012231
# 2018-07-06  14.832026  15.219398  14.461870  14.556562  105690560   0.015920
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269  -0.033149
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578  -0.005714
# ...

# %%
df['logrolling_std'] = df['simple_rtn'].apply(lambda x: x if x >= 0 else np.nan)

# %%
df['simple_rtn'] = df['simple_rtn'].apply(lambda x: x if x >= 0 else np.nan)

# %%
df['clog_rtn'] = df['simple_rtn'].apply(lambda x: x if x >= 0 else np.nan)

# %%
df['vsimple_rtn'] = df['simple_rtn'].apply(lambda x: x if x >= 0 else np.nan)

# %%
df['vlog_rtn'] = df['simple_rtn'].apply(lambda x: x if x >= 0 else np.nan)

# %%
df['logrolling_mean'] = df['simple_rtn'].apply(lambda x: x if x >= 0 else np.nan)

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-07-02  15.141922  15.796150  14.720118  15.667026  121806604        NaN
# 2018-07-03  15.408777  15.469035  14.720117  15.098881   89742495   0.017624
# 2018-07-04  14.780376  15.382955  14.737336  15.236615   80724110        NaN
# 2018-07-05  14.599602  15.064448  14.384395  14.634036   91199252        NaN
# 2018-07-06  14.832026  15.219398  14.461870  14.556562  105690560   0.015920
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# 2025-04-16  17.500000  18.059999  17.129999  18.000000  118725269        NaN
# 2025-04-17  17.400000  17.650000  17.200001  17.219999   77822578        NaN
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-07-03  15.408777  15.469035  14.720117  15.098881   89742495   0.017624
# 2018-07-06  14.832026  15.219398  14.461870  14.556562  105690560   0.015920
# 2018-07-09  15.038624  15.064449  14.711511  14.832026   80084021   0.013929
# 2018-07-12  15.460429  15.735895  14.332748  14.332748  179476511   0.078679
# 2018-07-16  15.357129  15.658418  15.116097  15.167748   91002211   0.012486
# ...               ...        ...        ...        ...        ...        ...
# 2025-04-09  16.330000  16.500000  14.580000  14.580000  218935510   0.057643
# 2025-04-10  17.959999  17.959999  17.500000  17.900000  253856136   0.099816
# 2025-04-14  17.920000  18.670000  17.830000  18.400000  142905610   0.006742
# 2025-04-15  18.100000  18.180000  17.820000  17.920000   87402246   0.010045
# ...

# %%
df.isnull().sum()
# Out:
# Price              Ticker
# Close              601138.SS    0
# High               601138.SS    0
# Low                601138.SS    0
# Open               601138.SS    0
# Volume             601138.SS    0
# simple_rtn                      0
# clog_rtn                        0
# vsimple_rtn                     0
# vlog_rtn                        0
# rolling_mean                    0
# rolling_std                     0
# Vrolling_mean                   0
# Vrolling_std                    0
# logrolling_mean                 0
# logrolling_std                  0
# vlogrolling_mean                0
# vlogrolling_std                 0
# logrolling_mean\t               0
# dtype: int64

# %%
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import plotly.express as px

# %%
print(df.head(10))
print(df.dtypes)
print(df.describe())
print(df)
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-07-03  15.408777  15.469035  14.720117  15.098881   89742495   0.017624
# 2018-07-06  14.832026  15.219398  14.461870  14.556562  105690560   0.015920
# 2018-07-09  15.038624  15.064449  14.711511  14.832026   80084021   0.013929
# 2018-07-12  15.460429  15.735895  14.332748  14.332748  179476511   0.078679
# 2018-07-16  15.357129  15.658418  15.116097  15.167748   91002211   0.012486
# 2018-07-20  14.892282  15.047231  14.401612  14.556561   71270453   0.021855
# 2018-07-24  15.546509  15.580943  14.806200  14.832024  125054476   0.046956
# 2018-07-26  15.288261  15.537900  15.176353  15.202179   66539746   0.002823
# 2018-07-31  14.780376  14.866459  14.677077  14.797593   29162201   0.001750
# 2018-08-07  13.385839  13.403055  12.946817  13.084549   45278678   0.027081
#
# ...

# %%
fig = px.scatter(
    x=df['Open'].squeeze(),
    y=df['Close'].squeeze(),
    title='Interactive Scatter Plot',
    labels={'x': 'Open', 'y': 'Close'}
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(
    x=df['Open'].squeeze(),
    y=df['Close'].squeeze(),
    title='Interactive line Plot',
    labels={'x': 'Open', 'y': 'Close'}
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
df = df.reset_index()

fig = go.Figure(data=[go.Candlestick(
                x=df['Date'],
                open=df['Open'].squeeze(),
                high=df['High'].squeeze(),
                low=df['Low'].squeeze(),
                close=df['Close'].squeeze())])

fig.update_layout(title='Candlestick Chart', xaxis_title='Date', yaxis_title='Price')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df
# Out:
# Price  index       Date      Close       High        Low       Open  \
# Ticker                   601138.SS  601138.SS  601138.SS  601138.SS
# 0          0 2018-07-03  15.408777  15.469035  14.720117  15.098881
# 1          1 2018-07-06  14.832026  15.219398  14.461870  14.556562
# 2          2 2018-07-09  15.038624  15.064449  14.711511  14.832026
# 3          3 2018-07-12  15.460429  15.735895  14.332748  14.332748
# 4          4 2018-07-16  15.357129  15.658418  15.116097  15.167748
# ..       ...        ...        ...        ...        ...        ...
# 814      814 2025-04-09  16.330000  16.500000  14.580000  14.580000
# 815      815 2025-04-10  17.959999  17.959999  17.500000  17.900000
# 816      816 2025-04-14  17.920000  18.670000  17.830000  18.400000
# 817      817 2025-04-15  18.100000  18.180000  17.820000  17.920000
# 818      818 2025-04-18  17.559999  17.650000  17.350000  17.400000
#
# Price      Volume simple_rtn  clog_rtn vsimple_rtn  vlog_rtn rolling_mean  \
# ...

# %%
fig = px.scatter(
    x=df['Open'].squeeze(),
    y=df['Close'].squeeze(),
    size=df['Volume'].squeeze(),
    color=df['High'].squeeze(),
    hover_name=df.index.astype(str),
    title='Bubble Chart: Open vs Close, Bubble = Volume, Color = High'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns = [col[0] if isinstance(col, tuple) else col for col in df.columns]


if 'level_0' in df.columns:
    df = df.drop(columns=['level_0'])
if 'index' in df.columns:
    df = df.drop(columns=['index'])


df = df.reset_index()



df.columns = [col[0] if isinstance(col, tuple) else col for col in df.columns]


df = df.reset_index()


df_plot = df[['Date', 'Open', 'Close']].copy()


df_melted = df_plot.melt(id_vars='Date', value_vars=['Open', 'Close'],
                         var_name='Price Type', value_name='Value')


fig = px.area(
    df_melted,
    x='Date',
    y='Value',
    color='Price Type',
    title='Area Chart: Open vs Close',
    labels={'Value': 'Price'}
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df
# Out:
#      level_0  index       Date      Close       High        Low       Open  \
# 0          0      0 2018-07-03  15.408777  15.469035  14.720117  15.098881
# 1          1      1 2018-07-06  14.832026  15.219398  14.461870  14.556562
# 2          2      2 2018-07-09  15.038624  15.064449  14.711511  14.832026
# 3          3      3 2018-07-12  15.460429  15.735895  14.332748  14.332748
# 4          4      4 2018-07-16  15.357129  15.658418  15.116097  15.167748
# ..       ...    ...        ...        ...        ...        ...        ...
# 814      814    814 2025-04-09  16.330000  16.500000  14.580000  14.580000
# 815      815    815 2025-04-10  17.959999  17.959999  17.500000  17.900000
# 816      816    816 2025-04-14  17.920000  18.670000  17.830000  18.400000
# 817      817    817 2025-04-15  18.100000  18.180000  17.820000  17.920000
# 818      818    818 2025-04-18  17.559999  17.650000  17.350000  17.400000
#
#         Volume  simple_rtn  clog_rtn  ...  vlog_rtn  rolling_mean  \
# ...

# %%
df.isnull().sum()
# Out:
# level_0              0
# index                0
# Date                 0
# Close                0
# High                 0
# Low                  0
# Open                 0
# Volume               0
# simple_rtn           0
# clog_rtn             0
# vsimple_rtn          0
# vlog_rtn             0
# rolling_mean         0
# rolling_std          0
# Vrolling_mean        0
# Vrolling_std         0
# logrolling_mean      0
# logrolling_std       0
# vlogrolling_mean     0
# vlogrolling_std      0
# logrolling_mean\t    0
# dtype: int64
